# %%
filename = 'kafka-clean.txt'

# %%
fh = open(filename, 'rt')

# %%
text = fh.read()

# %%
fh.close()

# %%
type(text)
# Out:
# str

# %%
text[:100]
# Out:
# 'I\n\n\nOne morning, when Gregor Samsa woke from troubled dreams, he found\nhimself transformed in his be'

# %%
with open(filename, 'rt') as fh:
    for i, line in enumerate(fh):
        print(i, line.strip())
        if i == 15:
            break
# Out:
# 0 I
# 1
# 2
# 3 One morning, when Gregor Samsa woke from troubled dreams, he found
# 4 himself transformed in his bed into a horrible vermin.  He lay on
# 5 his armour-like back, and if he lifted his head a little he could
# 6 see his brown belly, slightly domed and divided by arches into stiff
# 7 sections.  The bedding was hardly able to cover it and seemed ready
# 8 to slide off any moment.  His many legs, pitifully thin compared
# 9 with the size of the rest of him, waved about helplessly as he
# 10 looked.
# 11
# 12 "What's happened to me?" he thought.  It wasn't a dream.  His room,
# 13 a proper human room although a little too small, lay peacefully
# 14 between its four familiar walls.  A collection of textile samples
# 15 lay spread out on the table - Samsa was a travelling salesman - and

# %%
r = requests.get(bolsonaro)

# %%
r.text
# Out:
# '<!DOCTYPE HTML>\n<html lang="pt-br" itemscope itemtype="http://schema.org/WebPage"> <head><meta charset="utf-8"><link rel="preconnect" href="https://cocoon.globo.com"><link rel="dns-prefetch" href="https://cocoon.globo.com"><link rel="preconnect" href="https://globo-ab.globo.com"><link rel="dns-prefetch" href="https://globo-ab.globo.com"><link rel="preconnect" href="https://horizon.globo.com"><link rel="dns-prefetch" href="https://horizon.globo.com"><link rel="preconnect" href="https://horizon-schemas.globo.com"><link rel="dns-prefetch" href="https://horizon-schemas.globo.com"><link rel="preconnect" href="https://horizon-track.globo.com"><link rel="dns-prefetch" href="https://horizon-track.globo.com"><link rel="preconnect" href="https://www.google-analytics.com"><link rel="dns-prefetch" href="https://www.google-analytics.com"><link rel="preconnect" href="http://s.glbimg.com"><link rel="dns-prefetch" href="http://s.glbimg.com"><link rel="preconnect" href="https://s.glbimg.com"><link 
# ...
